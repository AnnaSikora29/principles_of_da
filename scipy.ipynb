# %% [markdown]
# ## scipy

# %%
# Numercial arrays.
import numpy as np

# Scientific Computing.
import scipy as sp

# Plotting.
import matplotlib.pyplot as plt

# %% [markdown]
# ### Resources
# https://docs.scipy.org/doc/scipy/tutorial/index.html

# %% [markdown]
# ### Fit a Line

# %%
# Range of x values.
x = np.linspace(-10.0, 10.0, 21)

# Range of y values.
y = 4.0 * x + 2.0 + np.random.normal(0.0, 3.0, x.shape)

# %%
# Plot x and y.
plt.plot(x, y, 'o', label='Data')

# %%
# Fit a line.
m, c = np.polyfit(x, y, 1)

# Show.
m, c
# Out:
# (np.float64(3.9612522788887525), np.float64(2.0533501187643215))

# %%
# Plot x and y.
plt.plot(x, y, 'o', label='Data')

# Plot the line.
plt.plot(x, m * x + c, label='Fit')

# %%
# Fit a line.
coeffs = np.polyfit(x, y, 1)

# Show.
coeffs
# Out:
# array([3.96125228, 2.05335012])

# %%
# Evaluate the polynomial.
f = np.polyval(coeffs, x)

# Show.
f
# Out:
# array([-37.55917267, -33.59792039, -29.63666811, -25.67541583,
#        -21.71416355, -17.75291128, -13.791659  ,  -9.83040672,
#         -5.86915444,  -1.90790216,   2.05335012,   6.0146024 ,
#          9.97585468,  13.93710696,  17.89835923,  21.85961151,
#         25.82086379,  29.78211607,  33.74336835,  37.70462063,
#         41.66587291])

# %%
# Show y.
y
# Out:
# array([-36.75192331, -37.8625573 , -31.57339578, -26.86442044,
#        -20.21318862, -15.3306844 , -11.49556803,  -4.52615712,
#        -11.61815911,   2.03635284,  -1.47078076,   4.29934172,
#         12.80409571,  12.80673688,  22.33260488,  20.61151928,
#         27.3403586 ,  28.09813657,  34.29423743,  35.28616732,
#         40.91763613])

# %%
# Evaluate the polynomial.
f = np.polyval(coeffs, x)

# Show.
y
# Out:
# array([-36.75192331, -37.8625573 , -31.57339578, -26.86442044,
#        -20.21318862, -15.3306844 , -11.49556803,  -4.52615712,
#        -11.61815911,   2.03635284,  -1.47078076,   4.29934172,
#         12.80409571,  12.80673688,  22.33260488,  20.61151928,
#         27.3403586 ,  28.09813657,  34.29423743,  35.28616732,
#         40.91763613])
