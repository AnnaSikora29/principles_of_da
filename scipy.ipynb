# %% [markdown]
# ## scipy

# %%
# Numercial arrays.
import numpy as np

# Scientific Computing.
import scipy as sp

# Plotting.
import matplotlib.pyplot as plt

# %% [markdown]
# ### Resources
# https://docs.scipy.org/doc/scipy/tutorial/index.html

# %% [markdown]
# ### Fit a Line

# %%
# Range of x values.
x = np.linspace(-10.0, 10.0, 21)

# Range of y values.
y = 4.0 * x + 2.0 + np.random.normal(0.0, 3.0, x.shape)

# %%
# Plot x and y.
plt.plot(x, y, 'o', label='Data')

# %%
# Fit a line.
m, c = np.polyfit(x, y, 1)

# Show.
m, c
# Out:
# (np.float64(4.0474555821019145), np.float64(2.3465413402252997))

# %%
# Plot x and y.
plt.plot(x, y, 'o', label='Data')

# Plot the line.
plt.plot(x, m * x + c, label='Fit')

# %%
# Fit a line.
coeffs = np.polyfit(x, y, 1)

# Show.
coeffs
# Out:
# array([4.04745558, 2.34654134])

# %%
# Evaluate the polynomial.
f = np.polyval(coeffs, x)

# Show.
f
# Out:
# array([-38.12801448, -34.0805589 , -30.03310332, -25.98564773,
#        -21.93819215, -17.89073657, -13.84328099,  -9.79582541,
#         -5.74836982,  -1.70091424,   2.34654134,   6.39399692,
#         10.4414525 ,  14.48890809,  18.53636367,  22.58381925,
#         26.63127483,  30.67873041,  34.726186  ,  38.77364158,
#         42.82109716])

# %%
# Show y.
y
# Out:
# array([-33.14519574, -38.87589566, -30.71580071, -26.99720812,
#        -23.51528492, -17.37374963, -10.59512488, -11.79631593,
#         -8.92269647,  -3.37405877,   4.83426668,  11.67208905,
#          6.67340765,  14.60688167,  20.03830501,  24.90648991,
#         33.0168476 ,  26.93193494,  33.09416167,  39.4967295 ,
#         39.31758527])

# %%
# Evaluate the polynomial.
f = np.polyval(coeffs, x)

# Show.
y
# Out:
# array([-33.14519574, -38.87589566, -30.71580071, -26.99720812,
#        -23.51528492, -17.37374963, -10.59512488, -11.79631593,
#         -8.92269647,  -3.37405877,   4.83426668,  11.67208905,
#          6.67340765,  14.60688167,  20.03830501,  24.90648991,
#         33.0168476 ,  26.93193494,  33.09416167,  39.4967295 ,
#         39.31758527])

# %% [markdown]
# ### Evaluate
# https://en.wikipedia.org/wiki/Coefficient_of_determination

# %%
# Sum of squares of residuals.
ss_res = np.sum((y - f)**2)

# Show.
ss_res
# Out:
# np.float64(205.68051878697287)

# %%
# Mean of y.
y_bar = np.mean(y)

# Show.
y_bar
# Out:
# np.float64(2.346541340225301)

# %%
# Total sum of squares.
ss_tot = np.sum((y - y_bar)**2)

# Show.
ss_tot
# Out:
# np.float64(12819.740969384682)

# %%
# Ratio.
ss_res / ss_tot
# Out:
# np.float64(0.016044046387377595)

# %%
# R^2 value.
1.0 - (ss_res / ss_tot)
# Out:
# np.float64(0.9839559536126224)

# %% [markdown]
# ### Using scipy

# %%
# Use scipy to fit a line.
fit = sp.stats.linregress(x, y)

# Show.
fit
# Out:
# LinregressResult(slope=np.float64(4.047455582101913), intercept=np.float64(2.346541340225301), rvalue=np.float64(0.9919455396404697), pvalue=np.float64(1.6237126266915382e-18), stderr=np.float64(0.11856988986429594), intercept_stderr=np.float64(0.7179763380658724))

# %%
# Slope.
fit.slope
# Out:
# np.float64(4.047455582101913)

# %%
# Intercept.
fit.intercept
# Out:
# np.float64(2.346541340225301)

# %%
# R value.
fit.rvalue
# Out:
# np.float64(0.9919455396404697)

# %% [markdown]
# ### End
